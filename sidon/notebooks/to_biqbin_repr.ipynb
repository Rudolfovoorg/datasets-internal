# %%
import glob
import json

# %%
instances_full_path = [i for i in glob.glob(
    '/home/beno/projects/datasets-internal/sidon/data/Advantage2_system1.8/*/*/*/*/*') if 'json' in i]

instances_full_path.sort()
partial_names = [ '_'.join(name[len('/home/beno/projects/datasets-internal/sidon/data/'):-len('.json')].split('/')) for name in instances_full_path]

partial_names
# Out:
# ['Advantage2_system1.8_send_8_m1_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m1_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m1_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m10_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m10_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m11_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m11_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m12_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m12_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m2_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m2_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m3_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m3_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m4_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m4_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m5_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m5_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m6_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m6_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m7_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m7_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m8_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m8_case9_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case0_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case0_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case1_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case1_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case2_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case2_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case3_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case3_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case4_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case4_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case5_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case5_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case6_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case6_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case7_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case7_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case8_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case8_beta0.0_J_qac',
#  'Advantage2_system1.8_send_8_m9_case9_beta0.0_J_log',
#  'Advantage2_system1.8_send_8_m9_case9_beta0.0_J_qac']

# %%
from sidion_qubo import Ising

# %%
from functools import wraps
from typing import Tuple
import scipy as sp
import numpy as np
from numpy import typing as npt


def to_sparse(qubo: npt.ArrayLike):
    """Converts a 2D array to the expected sparse coo_matrix representation.

    Args:
        qubo: 2D list or numpy array

    Returns:
        dict: a sparse QUBO representation needed as input for the Solver. It is as a json serializable dict.
    """
    qubo_sparse_coo = sp.sparse.coo_matrix(qubo)
    return {
        'shape': qubo_sparse_coo.shape,
        'nnz': qubo_sparse_coo.nnz,
        'row': qubo_sparse_coo.row.tolist(),
        'col': qubo_sparse_coo.col.tolist(),
        'data': qubo_sparse_coo.data.tolist()
    }

def qubo_to_biqbin_representation(qubo) -> dict:
    """Converts a dense qubo represantation 2D array to the expected biqbin format of a json serializable 
    dict with 'qubo' key and a sparse qubo represantation as value.

    Args:
        qubo: 2D list or numpy array

    Returns:
        dict: json serializable dictionary that Biqbin can parse. Save to file and pass the path to DataGetterJson.
    """
    if not np.all(np.asarray(qubo) % 1 == 0):
        raise ValueError("All QUBO values need to be integers!")

    return {
        'qubo': to_sparse(qubo)
    }

# %%
import networkx as nx
import numpy as np
isings = ['J_log', 'J_qac']

def ising2qubo(ising):
    Q, nodes = nx.attr_matrix(ising, edge_attr='J')
    Q = np.triu(Q, 1)
    node_h = nx.get_node_attributes(ising, 'h')
    L = np.array([node_h[node] for node in nodes])
    
    QUBO = 4*Q
    
    offset = -L.sum() + Q.sum()
    np.fill_diagonal(QUBO, 2*L - 2*Q.sum(axis=0) - 2*Q.sum(axis=1))

    return QUBO, offset

for i, instance in enumerate(instances_full_path):
    with open(instance, 'r') as f:
        data = json.load(f)

    ising = Ising().deserialize(data)
    filename = '_'.join(instance[len('/home/beno/projects/datasets-internal/sidon/data/'):-len('.json')].split('/')) + '.json'

    qubo, offset = ising2qubo(ising)
    qubo *= 28
    qubo_rounded = qubo.round()
    if not all(qubo.flat[i] - qubo_rounded.flat[i] < 0.00000001 for i in range(qubo.shape[0] * qubo.shape[0])):
        print(f"Oh nooo {instance}")
        break
    
    biqbin_data = qubo_to_biqbin_representation(qubo_rounded)
    biqbin_data['offset'] = offset * 28
    with open(f'/home/beno/projects/datasets-internal/biqbin/sidon/{filename}', 'w') as f:
        json.dump(biqbin_data, f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 32
#      29     print(f"Oh nooo {instance}")
#      30     break
# ---> 32 biqbin_data = qubo_to_biqbin_representation(qubo_rounded)
#      33 biqbin_data['offset'] = offset * 28
#      34 with open(f'/home/beno/projects/datasets-internal/{filename}', 'w') as f:
#
# Cell In[62], line 40, in qubo_to_biqbin_representation(qubo)
#      36 if not np.all(np.asarray(qubo) % 1 == 0):
#      37     raise ValueError("All QUBO values need to be integers!")
#      39 return {
# ---> 40     'qubo': to_sparse(qubo)
#      41 }
#
# Cell In[62], line 17, in to_sparse(qubo)
#       8 def to_sparse(qubo: npt.ArrayLike):
#       9     """Converts a 2D array to the expected sparse coo_matrix representation.
#      10
#      11     Args:
#    (...)     15         dict: a sparse QUBO representation needed as input for the Solver. It is as a json serializable dict.
#      16     """
# ---> 17     qubo_sparse_coo = sp.sparse.coo_matrix(qubo)
#      18     return {
#      19         'shape': qubo_sparse_coo.shape,
#      20         'nnz': qubo_sparse_coo.nnz,
#    (...)     23         'data': qubo_sparse_coo.data.tolist()
#      24     }
#
# File ~/anaconda3/envs/biqbin-pybind/lib/python3.13/site-packages/scipy/sparse/_coo.py:92, in _coo_base.__init__(self, arg1, shape, dtype, copy, maxprint)
#      89         raise ValueError(message)
#      91 index_dtype = self._get_index_dtype(maxval=max(self._shape))
# ---> 92 coords = M.nonzero()
#      93 self.coords = tuple(idx.astype(index_dtype, copy=False)
#      94                      for idx in coords)
#      95 self.data = getdata(M[coords], copy=copy, dtype=dtype)
#
# KeyboardInterrupt:

# %%
pwd
# Out:
# '/home/beno/projects/datasets-internal/sidon/notebooks'
